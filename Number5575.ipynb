# %%
for i in range(3):
    h1, m1, s1, h2, m2, s2 = map(int, input().split())
    start = h1 * 3600 + m1 * 60 + s1   # 출근 시간
    end = h2 * 3600 + m2 * 60 + s2   # 퇴근 시간
    t = end - start     # 근무 시간
    h = t // 3600 % 24
    m = t // 60 % 60
    s = t % 60
    print(h, m, s)
