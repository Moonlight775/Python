# %% [markdown]
# ## 사용자가 입력한 수 까지의 합 출력

# %%
num = int(input("어디까지 더할까요? "))

sum = 0
i = 1

while i <= num :
    sum = sum + i
    i = i + 1

print(sum)

# %% [markdown]
# ## 사용자가 입력한 단의 구구단 출력

# %%
dan = int(input("출력할 단을 입력하세요: "))

i = 1

while i <= 9:
    print('%d X %d = %d' %(dan, i, dan*i))
    i = i + 1
