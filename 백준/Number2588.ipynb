# %%
first = int(input())
second = input()
rev_list = list(reversed(second))

for i in rev_list :
    print(int(i) * first)

print(first * int(second))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720
