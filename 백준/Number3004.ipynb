# %%
N = int(input())    # 자르는 횟수

result = plus = 2   # result = 조각 개수, plus = 조각 증가 폭

for i in range(1, N) :
    result += plus

    # 홀수 항에서 조각 증가
    if i % 2 == 0 :
        plus += 1

print(result)
# Out:
# 3
# 6
