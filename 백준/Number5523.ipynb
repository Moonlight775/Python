# %%
num = int(input())
count_A = count_B = 0

for i in range(num) :
    A, B = map(int, input().split())

    if A > B :
        count_A += 1
    elif A < B :
        count_B += 1

print(count_A, count_B)
# Out:
# 4
# 100 0
# 5 6
# 40 50
# 74 75
# 1 3
